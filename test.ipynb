# %%
import numpy as np

# %%
import pandas as pd

# %%
import scipy as sp

# %%
df = pd.read_csv("maplike_survey_201612.csv")

# %%
df.describe()
# Out:
#               id        AGE    DEGREE        FAC   ITSKILLS  VISSKILLS  \
# count  40.000000  40.000000  40.00000  40.000000  40.000000  40.000000
# mean   20.500000  22.625000   0.77500   6.525000   5.175000   3.575000
# std    11.690452   2.695557   0.65974   2.571914   1.375379   1.337573
# min     1.000000  17.000000   0.00000   2.000000   3.000000   1.000000
# 25%    10.750000  21.000000   0.00000   4.000000   5.000000   3.000000
# 50%    20.500000  23.000000   1.00000   8.000000   5.000000   4.000000
# 75%    30.250000  24.000000   1.00000   9.000000   6.000000   4.250000
# max    40.000000  28.000000   2.00000   9.000000   7.000000   6.000000
#
#         C1_SQ001   C1_SQ002   C1_SQ003   C2_SQ003   C2_SQ001   C2_SQ002  \
# count  40.000000  40.000000  40.000000  40.000000  40.000000  40.000000
# mean    3.700000   4.425000   5.225000   2.650000   3.975000   4.400000
# std     1.505545   1.448031   1.609069   1.477177   1.804375   1.794579
# ...

# %%
df.C1_SQ001.mean()
# Out:
# 3.7

# %% [markdown]
# Calculating 95% confidence interval

# %%
from scipy import stats

# %%
mean = 98.249
sigma = 0.733
N = 130
stats.norm.interval(0.95, loc=mean, scale=sigma / np.sqrt(N))
# Out:
# (98.122997143856793, 98.375002856143198)

# %%
df
# Out:
#     g  id  AGE GENDER  DEGREE  FAC                       MAJOR  ITSKILLS  \
# 0   A   1   19      F       0    8                         GPA         5
# 1   A   2   23      F       1    8       public administration         3
# 2   A   3   17      M       0    3            Japanese Studies         7
# 3   A   4   25      M       2    8           political science         5
# 4   A   5   23      F       1    7  International Business Law         5
# 5   A   6   25      M       2    3         CHINESE LINGUISTICS         3
# 6   A   7   24      F       1    9       E-commerce Technology         7
# 7   A   8   23      F       1    3         Chinese Linguistics         4
# 8   A   9   21      M       0    4    Financial controllership         3
# 9   A  10   24      M       1    9                  e-commerce         6
# 10  B  11   23      F       0    4  global business management         3
# 11  B  12   23      F       1    8                   economics         3
# ...

# %% [markdown]
# Mean values for C1_SQ001, C1_SQ002, C1_SQ003

# %%
(df.C1_SQ001.mean(), df.C1_SQ002.mean(), df.C1_SQ003.mean())
# Out:
# (3.7, 4.425, 5.225)

# %% [markdown]
# Wilcoxon signed rank test

# %%
sp.stats.wilcoxon(df.C1_SQ001, df.C1_SQ002)
# Out:
# WilcoxonResult(statistic=23.0, pvalue=1.9367333159192657e-05)

# %%
23/np.sqrt(40), 113.5/np.sqrt(40)
# Out:
# (3.6366193091936361, 17.945925721455552)

# %%
sp.stats.wilcoxon(df.C1_SQ002, df.C1_SQ003)
# Out:
# WilcoxonResult(statistic=113.5, pvalue=0.0021365877374490685)

# %%
sp.stats.wilcoxon(df.C1_SQ001, df.C1_SQ003)
# Out:
# WilcoxonResult(statistic=62.0, pvalue=0.00013349783843432563)
